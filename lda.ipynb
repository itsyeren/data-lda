# %% [markdown]
# # Latent Dirichlet Allocation (LDA)

# %% [markdown]
# 🎯 The goal of this challenge is to find topics within an email corpus using the **LDA** algorithm (Unsupervised Learning in NLP).

# %% [markdown]
# ✉️ Here is a collection of more than 1000 ***unlabeled emails***. Let's try to ***extract topics*** from them!

# %%
import pandas as pd

url = 'https://d32aokrjazspmn.cloudfront.net/materials/lda_data'

data = pd.read_csv(url, sep=",", header=None)
data.columns = ['text']
data.head()

# %%
data.shape

# %% [markdown]
# ## (1) Preprocessing

# %% [markdown]
# ❓ **Question (Cleaning)** ❓ You're used to it by now... Clean up! Store the cleaned text in a new column "clean_text" of the DataFrame.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## (2) Latent Dirichlet Allocation model

# %% [markdown]
# ❓ **Question (Training)** ❓ Train an LDA model to extract potential topics.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## (3) Visualize the Potential Topics

# %% [markdown]
# 🎁 We have coded a function to print the words associated with each potential topic.

# %%
def print_topics(model, vectorizer):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names_out()[i], topic[i])
                        for i in topic.argsort()[:-10 - 1:-1]])

# %% [markdown]
# ❓ **Question** ❓ Print the topics extracted by LDA.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## (4) Predict the Document-Topic Mixture for a New Text

# %% [markdown]
# ❓ **Question (Prediction)** ❓
#
# Now that your LDA model is fitted, you can use it to predict the topics of a new text.
#
# 1. Vectorize the example
# 2. Use LDA on the vectorized example to predict the topics

# %%
example = ["My team performed poorly last season. Their best player was out injured and only played one game"]

# %%
# YOUR CODE HERE

# %% [markdown]
# 🏁 Congratulations! You have learned how to quickly apply LDA.
#
# 💾 Don't forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move on to the next challenge!
